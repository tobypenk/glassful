# %%
from database.Query import Query
q = Query("select * from ingredient limit 2;")
print(q.get_data())
# Out:
# [(1, 'agave+nectar', 1, 1, 1, 0, 'sweetener', None, 1, 1, 'A natural, syrupy sweetener derived from the agave plant, agave nectar is thinner and sweeter than honey.  It is grown primarily in Mexico and South Africa.', 0, 0, 'agave%20nectar', '/home/tobypenk/public_html/images/phpYkQLVJ5FxXJG', 'jpeg', 1, 1, 1, 'baking', 'sweetener', 3, '', 'agave', 'liquid', 1, 'syrup', Decimal('960.00000000'), Decimal('0E-8'), Decimal('256.00000000'), Decimal('0E-8'), Decimal('0.08422619'), Decimal('1.68452380'), '20-oz%20bottle', Decimal('10.00'), Decimal('20.0000000000'), 19912, 180, 1), (2, 'all%20purpose%20flour', 1, 1, 0, 1, 'sweetener', None, 1, 1, '', 0, 0, 'all%20purpose%20flour', '/home/tobypenk/public_html/images/phppQ47Dh4oohVr', 'png', 1, 1, 1, 'baking', 'binder', 1, '', 'wheat', 'powder', 1, 'flour', Decimal('440.00000000'), Decimal('0E-8'), Decimal('92.00000000'), Decimal('12.00000000'), Decimal('0.22822581'), Decimal('18.25806480'), '5-lb%20bag', Decimal('6.00'), Decimal('80.000000000
# ...

# %%
from database.APIConnection import APIConnection

total_with_id = APIConnection("http://raasipe.com/api/fetch_all_materials_api.php")

# %%
print(total_with_id.call())
# Out:
# ['2 1/2 lbs red potatoes|163', '3 tbsp apple cider vinegar|6', '3/4 cup mayonnaise|158', '1 tsp mustard powder|165', '1/4 cup parsley, chopped|53', '1 tbsp tarragon, chopped|166', '1/2 tbsp garlic, thinly sliced|32', '3 tbsp cornichons, finely chopped|164', '1/2 cup red onion, diced small|167', '1/2 cup celery, thinly sliced|14', '1 tsp kosher salt|38', '1/2 tsp black peppercorn, freshly ground|8', '2 cups all purpose flour|2', '1/2 tsp allspice, ground|3', '1/4 tsp baking soda|168', '1 tsp double-acting baking powder|169', '1 tsp kosher salt|38', '6 tbsp unsalted butter, chilled|65', '2 tsp cumin seeds|23', '1 tsp coriander seed|171', '1 tsp black peppercorn|8', '1 cup buttermilk|170', '1/2 tsp clove|19', '1 tsp green cardamom|173', '1/2 tsp nutmeg, grated|46', '1 stick small cinnamon, coarsely chopped|174', '1 large granny smith apple, diced|175', '5 tbsp unsalted butter, softened|65', '1/4 cup brown sugar, packed|176', '1/3 cup dried cranberry, coarsely chopped|26', '1/3 cup pecan
# ...
